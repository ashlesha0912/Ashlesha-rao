# %%
list1=[12,-7,64,5,-14]
for num in list1:
    if num>=0:
        print(num,end=", ")
# Out:
# 12, 64, 5,

# %%
list2=[]
x = [int(x) for x in input("Enter multiple value: ").split(",")] 
for n in x:
    if n>=0:
        list2.append(n)
print("list of positive nos. is: ",list2)
# Out:
# Enter multiple value:  12,14,-95,3
# list of positive nos. is:  [12, 14, 3]
