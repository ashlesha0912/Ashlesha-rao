# %%
mylist1=[23,478,82,64,74,90]
mylist1.append(45)
print(mylist1)
mylist2=["red","green","pink","black"]
mylist2.append("blue")
print(mylist2)
# Out:
# [23, 478, 82, 64, 74, 90, 45]
# ['red', 'green', 'pink', 'black', 'blue']

# %%
mydict={"C":"easy","C++":"moderate","Python":"tough"}
del mydict[ "C"]
print(mydict)
# Out:
# {'C++': 'moderate', 'Python': 'tough'}

# %%
mytuple=(74,83,738,28,56,27,89,10,477)
print(mytuple)
print(mytuple[1:5])
# Out:
# (74, 83, 738, 28, 56, 27, 89, 10, 477)
# (83, 738, 28, 56)
