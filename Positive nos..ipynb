# %%
list1=[]
i=0
while i<5:
    x=int(input("Enter positive no."))
    list1.append(x)
    for x in list1:
        if x>0:
            print(x)
    i=i+1
# Out:
# Enter positive no. 12
# 12
# Enter positive no. -14
# 12
# Enter positive no. 5
# 12
# 5
# Enter positive no. 64
# 12
# 5
# 64
# Enter positive no. -7
# 12
# 5
# 64

# %%
list2=[12,14,-95,3]
del list2[2]
print(list2)
# Out:
# [12, 14, 3]
